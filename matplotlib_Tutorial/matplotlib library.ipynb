# %% [markdown]
# # MatplotLib Tutorial :

# %% [markdown]
# - 𝐓𝐨 𝐮𝐬𝐞 𝐨𝐧𝐥𝐲 𝐩𝐥𝐨𝐭 𝐭𝐡𝐞 𝐠𝐫𝐚𝐩𝐡 𝐮𝐬𝐢𝐧𝐠 𝐭𝐡𝐢𝐬 𝐦𝐚𝐭𝐩𝐥𝐨𝐭𝐥𝐢𝐛 𝐥𝐢𝐛𝐫𝐚𝐫𝐲 :

# %%
# Import library :
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = [1,2,3,4,5]
df
# Out:
# [1, 2, 3, 4, 5]

# %%
#Iterator:

mytuple = ("Apple","banana","cheery")
myit = iter(mytuple)
myit

# %%
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# Apple
# banana
# cheery

# %%
import numpy as np

# %%
# Simple Example:

x=np.arange(0,10)    
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %% [markdown]
# - 𝐒𝐜𝐚𝐭𝐭𝐞𝐫 𝐏𝐥𝐨𝐭 :

# %%
#ploting using matplotlib

#plt scatter

plt.scatter(x,y,c='g') 
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %%
y=x*x     #curved shape diagram:

# %%
# plt plot

plt.plot(x,y,'r*', linestyle='dashed', linewidth=2, markersize=12)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('2D Diagram')
# Out:
# Text(0.5, 1.0, '2D Diagram')

# %%
#create subplot

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x=np.arange(1,11)
y = 3 * x + 5
plt.title('Matplot demo')
plt.xlabel('x-axis caption')
plt.ylabel('y-axis caption')
plt.plot(x,y,'g')

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# - 𝐁𝐚𝐫 𝐏𝐥𝐨𝐭 :

# %%
# bar plot

x=[1,2,3,4]
y=[3,4,6,7]

x2=[4,7,3,6]
y2=[2,4,6,8]

plt.bar(x,y,)
plt.bar(x2,y2,color ='g')
plt.title('Bar graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# - 𝐇𝐢𝐬𝐭𝐨𝐠𝐫𝐚𝐦𝐬 :

# %%
a=np.array([22,5,6,48,40,66,58,75,46,62,5,6,2,88,52,14,21,5])
plt.hist(a)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# - 𝐁𝐨𝐱 𝐏𝐥𝐨𝐭 :

# %%
# Box plot:

data = [np.random.normal(0, std, 100) for std in range(1,4)]

#Rectangular Box plot
plt.boxplot(data)       #vert=True, patch_artist=False
plt.show()

# %% [markdown]
# - 𝐏𝐢 𝐂𝐡𝐚𝐫𝐭 :

# %%
#data to plot
labels = "python","power-Bi","sql","AI"
sizes = [215,200,195,255]
colors = ['yellow','gold','skyblue','green']
explode = (0,0,0,0.5) #explode to data

#plot
plt.pie(sizes, explode, labels, colors, autopct='%1.1f%%', shadow=False)
plt.axis('equal')
plt.show()
